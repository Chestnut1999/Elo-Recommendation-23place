# %%
import sys
import pandas as pd
import numpy as np
import datetime
import glob
import gc
import os

#========================================================================
# Args
#========================================================================
key = 'card_id'
target = 'target'
ignore_list = [key, target, 'merchant_id', 'first_active_month']

win_path = f'../features/4_winner/*.gz'
fname=''
# submit = pd.read_csv('../input/sample_submission.csv')
submit = []

HOME = os.path.expanduser('~')
sys.path.append(f"{HOME}/kaggle/data_analysis/library/")
import utils
from preprocessing import get_ordinal_mapping
from utils import logger_func
try:
    if not logger:
        logger=logger_func()
except NameError:
    logger=logger_func()

start_time = "{0:%Y%m%d_%H%M%S}".format(datetime.datetime.now())
# Out:
# 2019-01-21 09:48:37,917 utils 396 [INFO]    [logger_func] start

# %%
#  不要なカラムを削除
cv_feim = pd.read_csv('../first_month_model/old_201712/0118_194_valid_lgb_lr0.02_77feats_3seed_31leaves_iter281_OUT0_CV1.1666834120527463_LB.csv')
drop_feim_cols = [col for col in cv_feim.columns if col.count('importance_') or col.count('rank_')]
cv_feim.drop(drop_feim_cols, axis=1, inplace=True)
drop_feim_cols = [col for col in cv_feim.columns if col.count('importance') and not(col.count('avg'))]
cv_feim.drop(drop_feim_cols, axis=1, inplace=True)
cv_feim.to_csv( f'../first_month_model/old_201712/0118_194_valid_lgb_lr0.02_77feats_3seed_31leaves_iter281_OUT0_CV1.1666834120527463_LB.csv', index=False)
sys.exit()

# %% [markdown]
# ### One by One Valid Features

# %%
import sys
import pandas as pd
pd.set_option('max_rows', 300)
### multi feature pred valid
# df = pd.read_csv('../output/0107_114_elo_multi_feat_valid_lr0.01.csv')
# df1 = pd.read_csv('../output/0107_131_elo_multi_feat_valid_lr0.01.csv')


# df = pd.read_csv('../output/0117_231_elo_multi_feat_valid_lr0.02.csv')
# df = pd.read_csv('../output/0117_233_elo_multi_feat_valid_lr0.02.csv')
# df = pd.read_csv('../output/0117_234_elo_multi_feat_valid_lr0.02.csv')
# df = pd.read_csv('../output/0118_001_elo_multi_feat_valid_lr0.02.csv')
# df = pd.read_csv('../output/0118_143_elo_multi_feat_valid_lr0.1.csv')
df = pd.read_csv('../output/0119_162_elo_multi_feat_valid_lr0.1.csv')
        
select_feats = df.iloc[-1, :][df.iloc[-1, :]>1].sort_values()
# select_feats = df.iloc[-2, :][df.iloc[-2, :]>1].sort_values()

# base
base_score = select_feats.loc['base']
# select_feats = select_feats[select_feats>=base_score]
select_feats = select_feats[select_feats<=base_score]
# select_feats = select_feats[select_feats>3.6575]
# select_feats = select_feats[select_feats<30.19]
display(select_feats)
# Out:
# 454_lag0_-2_auth1_purchase_amount_mean@                 1.342067
# 86_city_auth_mean@                                      1.342395
# 60_new_purchase_amount_min@                             1.342417
# 82_auth1_0_hist_purchase_date_min_diff@                 1.342421
# 30_hist_dayofweek_nunique@                              1.342427
# 229_lag0_-2_auth0_cat1_yyyy_week_nunique@               1.342507
# 218_lag0_-2_auth0_cat1_month_lag_std@                   1.342544
# 299_lag0_-2_cat1_first_buy@                             1.342551
# 14_new_category_2_1_0_mean                              1.342654
# 450_lag0_-2_auth1_month_diff_mean@                      1.342659
# 13_hist_category_3_C_mean                               1.342711
# 46_hist_purchase_date_uptonow@                          1.342760
# 114_auth1_yyyymm_ratio@                                 1.342789
# 320_new_cat0_installments_isnull_sum@                   1.342809
# 342_new_cat0_term_from_now@                             1.342819
# 289_lag0_-2_auth1_cat1_purchase_amount_over_max@        1.342826
# 8_hist_category_2_3_0_mean                              1.342842
# 409_lag0_-2_auth0_purchase_amount_max@                  1.342845
# 317_new_cat0_elapsed_time_from_first@                   1.342847
# 19_new_category_3_A_mean                                1.342880
# 16_new_category_2_3_0_mean                              1.342904
# 337_new_cat0_purchase_amount_over_mean@                 1.342930
# 10_hist_category_2_5_0_mean                             1.342941
# 346_new_cat1_amount_per_installments_sum@               1.342968
# 448_lag0_-2_auth1_merchant_id_isnull_sum@               1.342973
# 83_diff_last_first_authorized_flag_mean@                1.342990
# 85_change_main_city_flg@                                1.343000
# 302_new_cat0_amount_per_installments_sum@               1.343016
# 255_lag0_-2_auth1_cat0_merchant_category_id_nunique@    1.343071
# 340_new_cat0_purchase_amount_sum@                       1.343076
# 151_auth1_installments_null_cnt@                        1.343140
# 125_auth1_category_2_1_0_purchase_amount_min@           1.343165
# 478_auth0_new_lag1_purchase_amount_min@                 1.343170
# 283_lag0_-2_auth1_cat1_month_diff_mean@                 1.343191
# 62_new_purchase_date_average@                           1.343196
# 445_lag0_-2_auth1_installments_sum@                     1.343270
# 443_lag0_-2_auth1_installments_per_90days@              1.343270
# 137_auth1_category_2_4_0_diff_days_mean_ratio@          1.343295
# 156_new_installments_null_cnt@                          1.343334
# 349_new_cat1_first_buy@                                 1.343337
# 26_hist_category_1_mean@                                1.343345
# 296_lag0_-2_auth1_cat1_yyyy_week_nunique@               1.343357
# 113_auth1_yyyy_week_ratio@                              1.343358
# 260_lag0_-2_auth1_cat0_purchase_amount_max@             1.343385
# 397_lag0_-2_auth0_installments_max@                     1.343397
# 425_lag0_-2_auth1_category_2_null_cnt_mean@             1.343431
# 435_lag0_-2_auth1_dummie_category_2_NA_mean@            1.343431
# 34_hist_installments_sum@                               1.343458
# 74_auth0_hist_category_2_mean_mean@                     1.343472
# 412_lag0_-2_auth0_purchase_amount_over_max@             1.343506
# base                                                    1.343547
# Name: 5, dtype: float64

# %% [markdown]
# ### Move Feature

# %%
import shutil
import glob
move_list = glob.glob('../features/1_first_valid/*.gz')
# move_list = glob.glob('../features/2_second_valid/*.gz')
# move_list = glob.glob('../features/3_third_valid/*.gz')
# feat_list = list(select_feats[select_feats<3.653].index)
# feat_list = list(select_feats.index)[6:7]
feat_list = list(select_feats.index)

for feat in feat_list:
    move_path = [move for move in move_list if move.count(feat[4:])]
    for path in move_path:
        try:
            print(path)
#             shutil.move(path, '../features/5_tmp/')
#             shutil.move(path, '../features/1_first_valid/')
            shutil.move(path, '../features/2_second_valid/')
#             shutil.move(path, '../features/3_third_valid/')
#             print(path)
        except Error:
            print(f"Error: {path}")
# Out:
# ../features/1_first_valid/111_ker_test_weekofyear@.gz
# ../features/1_first_valid/111_ker_train_weekofyear@.gz
# ../features/1_first_valid/165_fe3_train_unix_first_active_month@.gz
# ../features/1_first_valid/172_fe4_train_lag0_-3_unix_first_active_month@.gz
# ../features/1_first_valid/168_fe3_test_unix_first_active_month@.gz
# ../features/1_first_valid/111_ker_test_month@.gz
# ../features/1_first_valid/111_ker_train_month@.gz
# ../features/1_first_valid/165_fe3_test_unix_first_active_month@.gz
# ../features/1_first_valid/172_fe4_test_lag0_-3_unix_first_active_month@.gz
# ../features/1_first_valid/168_fe3_train_unix_first_active_month@.gz
# ../features/1_first_valid/148_sss_test_state_id_16_auth1_installments_mean@.gz
# ../features/1_first_valid/171_fe3_train_auth1_new_lag1_2_purchase_amount_over_min@.gz
# ../features/1_first_valid/165_fe3_train_lag0_-2_auth0_cat0_merchant_id_isnull_mean@.gz
# ../features/1_first_valid/165_fe3_test_lag0_-2_auth1_cat0_dummie_category_2_2.0_sum@.gz
# ../features/1_first_valid/173_fe3_train_auth0_new_lag0_-4_purchase_amount_over_max@.gz
# ../features/1_first_valid/165_fe3_train_lag0_-2_auth1_cat1_amount_per_installments_sum@.gz
# ../features/1_first_valid/174_fe3_test_auth0_new_lag0_-5_amount_per_90days@.gz
# ../features/1_first_valid/111_ker_test_hist_authorized_flag_sum@.gz
# ../features/1_first_valid/165_fe3_train_lag0_-2_auth1_cat0_installments_sum@.gz
# ../features/1_first_valid/170_fe3_train_auth1_new_lag1_installments_mean@.gz
# ../features/1_first_valid/174_fe3_test_auth0_new_lag0_-5_category_1_sum@.gz
# ../features/1_first_valid/165_fe3_test_lag0_-2_auth1_cat1_installments_std@.gz
# ../features/1_first_valid/110_ker_train_auth_category_2_4.0_mean.gz
# ../features/1_first_valid/170_fe3_train_auth0_new_lag1_card_id_size@.gz
# ../features/1_first_valid/172_fe4_train_lag0_-3_auth1_freq_per_90days@.gz
# ../features/1_first_valid/111_ker_train_purchase_amount_total@.gz
# ../features/1_first_valid/166_fe3_test_new_cat0_month_lag_mean@.gz
# ../features/1_first_valid/119_ath_test_auth1_0_hist_purchase_date_min_diff@.gz
# ../features/1_first_valid/123_mai_train_diff_hist_new_main_city_ratio@.gz
# ../features/1_first_valid/165_fe3_test_lag0_-2_auth1_cat0_month_diff_mean@.gz
# ../features/1_first_valid/172_fe4_train_lag0_-3_auth1_dummie_category_2_3.0_mean@.gz
# ../features/1_first_valid/168_fe3_train_lag0_-2_auth0_month_diff_mean@.gz
# ../features/1_first_valid/111_ker_test_new_installments_max@.gz
# ../features/1_first_valid/166_fe3_test_feature_1@.gz
# ../features/1_first_valid/119_ath_test_auth1_0_hist_purchase_date_max_diff@.gz
# ../features/1_first_valid/170_fe3_train_auth1_new_lag1_purchase_amount_over_mean@.gz
# ../features/1_first_valid/165_fe3_train_lag0_-2_auth0_cat1_month_lag_mean@.gz
# ../features/1_first_valid/148_sss_test_state_id_-1_auth1_installments_mean@.gz
# ../features/1_first_valid/165_fe3_test_lag0_-2_auth1_cat1_month_lag_std@.gz
# ../features/1_first_valid/172_fe4_test_lag0_-3_auth1_card_id_size@.gz
# ../features/1_first_valid/171_fe3_train_auth1_new_lag1_2_purchase_amount_max@.gz
# ../features/1_first_valid/110_ker_train_auth_category_3_B_mean.gz
# ../features/1_first_valid/168_fe3_test_lag0_-2_auth0_dummie_category_2_3.0_sum@.gz
# ../features/1_first_valid/168_fe3_test_lag0_-2_auth1_term_from_now@.gz
# ../features/1_first_valid/168_fe3_test_lag0_-2_auth1_dummie_category_2_2.0_sum@.gz
# ../features/1_first_valid/173_fe3_train_auth0_new_lag0_-4_purchase_amount_max@.gz
# ../features/1_first_valid/111_ker_train_hist_month_lag_max@.gz
# ../features/1_first_valid/130_ddf_test_hist_trans5_date_diff_mean@.gz
# ../features/1_first_valid/165_fe3_train_lag0_-2_auth1_cat1_purchase_amount_mean@.gz
# ../features/1_first_valid/165_fe3_test_lag0_-2_auth0_cat0_installments_per_90days@.gz
# ../features/1_first_valid/172_fe4_test_lag0_-3_auth0_dummie_category_2_2.0_mean@.gz
# ../features/1_first_valid/168_fe3_train_lag0_-2_auth1_month_lag_mean@.gz
# ../features/1_first_valid/166_fe3_train_feature_2@.gz
# ../features/1_first_valid/166_fe3_train_new_cat0_dummie_category_2_5.0_sum@.gz
# ../features/1_first_valid/170_fe3_train_auth0_new_lag1_freq_per_90days@.gz
# ../features/1_first_valid/168_fe3_test_lag0_-2_auth0_unix_date_max@.gz
# ../features/1_first_valid/165_fe3_test_lag0_-2_auth0_cat1_installments_mean@.gz
# ../features/1_first_valid/171_fe3_train_auth1_new_lag1_2_amount_per_90days@.gz
# ../features/1_first_valid/172_fe4_train_lag0_-3_auth0_merchant_id_isnull_sum@.gz
# ../features/1_first_valid/174_fe3_test_auth0_new_lag0_-5_installments_per_90days@.gz
# ../features/1_first_valid/165_fe3_train_lag0_-2_auth1_cat1_merchant_id_nunique@.gz
# ../features/1_first_valid/140_cow_train_auth0_continuous_week_std@.gz
# ../features/1_first_valid/165_fe3_train_lag0_-2_auth0_cat0_term_from_now@.gz
# ../features/1_first_valid/168_fe3_train_lag0_-2_first_buy@.gz
# ../features/1_first_valid/168_fe3_test_lag0_-2_auth0_installments_per_90days@.gz
# ../features/1_first_valid/165_fe3_train_lag0_-2_auth0_cat0_installments_std@.gz
# ../features/1_first_valid/172_fe4_train_lag0_-3_auth1_category_2_null_cnt_sum@.gz
# ../features/1_first_valid/166_fe3_train_new_cat0_installments_per_90days@.gz
# ../features/1_first_valid/111_ker_test_hist_purchase_amount_sum@.gz
# ../features/1_first_valid/171_fe3_train_auth0_new_lag1_2_purchase_amount_over_max@.gz
# ../features/1_first_valid/166_fe3_train_new_cat0_freq_per_90days@.gz
# ../features/1_first_valid/166_fe3_train_new_cat0_unix_date_min@.gz
# ../features/1_first_valid/171_fe3_test_auth0_new_lag1_2_card_id_size@.gz
# ../features/1_first_valid/172_fe4_test_lag0_-3_auth1_purchase_amount_min@.gz
# ../features/1_first_valid/165_fe3_train_lag0_-2_auth0_cat0_merchant_id_nunique@.gz
# ../features/1_first_valid/110_ker_test_auth_category_3_B_mean.gz
# ../features/1_first_valid/166_fe3_train_new_cat1_installments_std@.gz
# ../features/1_first_valid/168_fe3_train_lag0_-2_auth0_dummie_category_2_NA_mean@.gz
# ../features/1_first_valid/153_nlc_train_auth1_category_3_null_cnt@.gz
# ../features/1_first_valid/172_fe4_train_lag0_-3_auth1_dummie_category_2_1.0_mean@.gz
# ../features/1_first_valid/165_fe3_train_lag0_-2_auth0_cat0_dummie_category_2_NA_mean@.gz
# ../features/1_first_valid/145_cat_train_auth0_category_1_Y_diff_days_std@.gz
# ../features/1_first_valid/168_fe3_train_lag0_-2_auth1_installments_min@.gz
# ../features/1_first_valid/165_fe3_test_lag0_-2_auth0_cat1_merchant_id_isnull_mean@.gz
# ../features/1_first_valid/168_fe3_test_lag0_-2_auth1_installments_max@.gz
# ../features/1_first_valid/111_ker_train_new_installments_max@.gz
# ../features/1_first_valid/166_fe3_test_new_cat1_installments_sum@.gz
# ../features/1_first_valid/168_fe3_train_lag0_-2_auth1_card_id_size@.gz
# ../features/1_first_valid/174_fe3_test_auth0_new_lag0_-5_card_id_size@.gz
# ../features/1_first_valid/172_fe4_train_lag0_-3_auth1_installments_min@.gz
# ../features/1_first_valid/171_fe3_train_auth0_new_lag1_2_installments_mean@.gz
# ../features/1_first_valid/165_fe3_train_lag0_-2_auth0_cat0_purchase_amount_over_sum@.gz
# ../features/1_first_valid/174_fe3_test_auth0_new_lag0_-5_category_1_mean@.gz
# ../features/1_first_valid/165_fe3_train_lag0_-2_auth0_cat0_purchase_amount_over_mean@.gz
# ../features/1_first_valid/172_fe4_test_lag0_-3_auth1_amount_per_90days@.gz
# ../features/1_first_valid/125_cat_test_category3_C_hist_authorized_flag_mean@.gz
# ../features/1_first_valid/165_fe3_train_lag0_-2_auth1_cat1_installments_isnull_mean@.gz
# ../features/1_first_valid/170_fe3_test_auth0_new_lag1_installments_mean@.gz
# ../features/1_first_valid/171_fe3_train_auth1_new_lag1_2_merchant_category_id_nunique@.gz
# ../features/1_first_valid/165_fe3_test_lag0_-2_auth0_cat0_purchase_amount_over_mean@.gz
# ../features/1_first_valid/125_cat_test_category2_5_hist_authorized_flag_mean@.gz
# ../features/1_first_valid/168_fe3_test_lag0_-2_auth1_dummie_category_2_3.0_mean@.gz
# ../features/1_first_valid/168_fe3_test_lag0_-2_auth1_category_2_null_cnt_mean@.gz
# ../features/1_first_valid/124_sam_train_auth0_same_date_purchase_max@.gz
# ../features/1_first_valid/168_fe3_train_lag0_-2_auth1_dummie_category_2_3.0_mean@.gz
# ../features/1_first_valid/171_fe3_test_auth0_new_lag1_2_installments_sum@.gz
# ../features/1_first_valid/166_fe3_test_new_cat1_purchase_amount_over_max@.gz
# ../features/1_first_valid/166_fe3_test_new_cat1_purchase_amount_over_min@.gz
# ../features/1_first_valid/165_fe3_train_lag0_-2_auth1_cat0_dummie_category_2_1.0_mean@.gz
# ../features/1_first_valid/168_fe3_test_lag0_-2_auth0_freq_per_90days@.gz
# ../features/1_first_valid/111_ker_test_new_installments_min@.gz
# ../features/1_first_valid/165_fe3_train_lag0_-2_auth1_cat0_merchant_id_isnull_sum@.gz
# ../features/1_first_valid/165_fe3_test_lag0_-2_auth1_cat0_merchant_category_id_nunique@.gz
# ../features/1_first_valid/118_ah0_test_auth0_hist_month_lag_var@.gz
# ../features/1_first_valid/111_ker_test_hist_category_2_mean_mean@.gz
# ../features/1_first_valid/168_fe3_test_lag0_-2_auth0_amount_per_90days@.gz
# ../features/1_first_valid/172_fe4_train_lag0_-3_auth0_dummie_category_2_2.0_sum@.gz
# ../features/1_first_valid/165_fe3_train_lag0_-2_cat1_elapsed_time_from_first@.gz
# ../features/1_first_valid/165_fe3_test_lag0_-2_auth0_cat0_month_lag_std@.gz
# ../features/1_first_valid/166_fe3_test_new_cat1_first_buy@.gz
# ../features/1_first_valid/165_fe3_test_lag0_-2_auth1_cat0_unix_date_max@.gz
# ../features/1_first_valid/166_fe3_test_new_cat0_merchant_id_nunique@.gz
# ../features/1_first_valid/166_fe3_test_new_cat0_purchase_amount_over_min@.gz
# ../features/1_first_valid/172_fe4_train_lag0_-3_auth0_dummie_category_2_NA_sum@.gz
# ../features/1_first_valid/170_fe3_train_auth0_new_lag1_merchant_id_nunique@.gz
# ../features/1_first_valid/165_fe3_train_lag0_-2_auth0_cat0_dummie_category_2_4.0_mean@.gz
# ../features/1_first_valid/110_ker_test_auth_category_2_1.0_mean.gz
# ../features/1_first_valid/165_fe3_test_lag0_-2_auth1_cat0_amount_per_installments_mean@.gz
# ../features/1_first_valid/168_fe3_test_lag0_-2_auth0_merchant_id_isnull_sum@.gz
# ../features/1_first_valid/170_fe3_train_auth1_new_lag1_purchase_amount_mean@.gz
# ../features/1_first_valid/111_ker_test_new_installments_var@.gz
# ../features/1_first_valid/165_fe3_test_lag0_-2_auth1_cat0_installments_sum@.gz
# ../features/1_first_valid/171_fe3_train_auth1_new_lag1_2_purchase_amount_over_sum@.gz
# ../features/1_first_valid/118_ah0_test_auth0_hist_month_lag_mean@.gz
# ../features/1_first_valid/145_cat_train_new_category_2_2_0_purchase_amount_max@.gz
# ../features/1_first_valid/170_fe3_train_auth0_new_lag1_installments_mean@.gz
# ../features/1_first_valid/172_fe4_test_lag0_-3_auth1_unix_date_min@.gz
# ../features/1_first_valid/172_fe4_test_lag0_-3_auth1_dummie_category_2_3.0_sum@.gz
# ../features/1_first_valid/168_fe3_train_lag0_-2_auth0_installments_isnull_sum@.gz
# ../features/1_first_valid/153_nlc_train_auth1_null_cnt@.gz
# ../features/1_first_valid/170_fe3_train_auth0_new_lag1_installments_sum@.gz
# ../features/1_first_valid/173_fe3_test_auth0_new_lag0_-4_purchase_amount_sum@.gz
# ../features/1_first_valid/171_fe3_test_auth1_new_lag1_2_purchase_amount_over_max@.gz
# ../features/1_first_valid/174_fe3_train_auth0_new_lag0_-5_purchase_amount_max@.gz
# ../features/1_first_valid/166_fe3_train_new_cat0_merchant_id_isnull_mean@.gz
# ../features/1_first_valid/165_fe3_test_lag0_-2_auth1_cat1_month_diff_mean@.gz
# ../features/1_first_valid/165_fe3_test_lag0_-2_auth0_cat0_term@.gz
# ../features/1_first_valid/111_ker_train_hist_weekend_sum@.gz
# ../features/1_first_valid/165_fe3_test_lag0_-2_auth0_cat1_installments_isnull_sum@.gz
# ../features/1_first_valid/165_fe3_train_lag0_-2_auth1_cat0_purchase_amount_min@.gz
# ../features/1_first_valid/110_ker_test_hist_category_2_2.0_mean.gz
# ../features/1_first_valid/165_fe3_test_lag0_-2_auth1_cat1_installments_min@.gz
# ../features/1_first_valid/125_cat_test_category2_1_hist_authorized_flag_mean@.gz
# ../features/1_first_valid/172_fe4_test_lag0_-3_auth1_yyyy_week_nunique@.gz
# ../features/1_first_valid/170_fe3_train_auth0_new_lag1_amount_per_installments_sum@.gz
# ../features/1_first_valid/170_fe3_test_auth1_new_lag1_card_id_size@.gz
# ../features/1_first_valid/165_fe3_test_lag0_-2_auth1_0_term@.gz
# ../features/1_first_valid/168_fe3_train_lag0_-2_auth0_purchase_amount_over_mean@.gz
# ../features/1_first_valid/157_trm_train_auth1_freq_per_days_personal_term@.gz
# ../features/1_first_valid/117_ah1_train_auth1_hist_category_2_mean_mean@.gz
# ../features/1_first_valid/165_fe3_train_lag0_-2_auth0_cat1_unix_date_min@.gz
# ../features/1_first_valid/133_ddf_test_new_date_diff_std@.gz
# ../features/1_first_valid/166_fe3_train_new_cat0_amount_per_installments_mean@.gz
# ../features/1_first_valid/172_fe4_train_lag0_-3_auth0_purchase_amount_over_max@.gz
# ../features/1_first_valid/172_fe4_test_lag0_-3_auth1_term_from_now@.gz
# ../features/1_first_valid/172_fe4_train_lag0_-3_auth0_purchase_amount_min@.gz
# ../features/1_first_valid/172_fe4_train_lag0_-3_auth0_dummie_category_2_1.0_mean@.gz
# ../features/1_first_valid/165_fe3_train_lag0_-2_auth1_cat1_purchase_amount_over_min@.gz
# ../features/1_first_valid/172_fe4_test_lag0_-3_auth0_card_id_size@.gz
# ../features/1_first_valid/165_fe3_train_unix_first_active_month@.gz
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-37-4343502511c4> in <module>()
#      16 #             shutil.move(path, '../features/1_first_valid/')
# ---> 17             shutil.move(path, '../features/2_second_valid/')
#      18 #             shutil.move(path, '../features/3_third_valid/')
#
# ~/anaconda3/lib/python3.6/shutil.py in move(src, dst, copy_function)
#     541         if os.path.exists(real_dst):
# --> 542             raise Error("Destination path '%s' already exists" % real_dst)
#     543     try:
#
# Error: Destination path '../features/2_second_valid/165_fe3_train_unix_first_active_month@.gz' already exists
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-4343502511c4> in <module>()
#      18 #             shutil.move(path, '../features/3_third_valid/')
#      19 #             print(path)
# ---> 20         except Error:
#      21             print(f"Error: {path}")
#
# NameError: name 'Error' is not defined

# %% [markdown]
# ### Decrease Score

# %%
import sys
import pandas as pd
pd.set_option("max_rows", 200)
# df = pd.read_csv('../output/0107_08_elo_decrease_features.csv')
df = pd.read_csv('../output/0121_0831_elo_decrease_features_lr0.1.csv').drop(['flg', 'Unnamed: 0'], axis=1)
df = df[df['remove_flg']==1]
df.sort_values(by=['score'], inplace=True)
# base_score = df[df['feature']=='base']['score'].values[0]
# print(base_score)
dec_feat = df
# dec_feat = df[df['score']<=base_score]
# dec_feat = df[df['score']<1.115]
dec_feat.sort_values(by='score', inplace=True)
dec_feat
# Out:
#                                   feature     score  num  remove_flg  \
# 0  130_ddf_all_hist_last5_date_diff_mean@  3.663836  115         1.0
#
#    remove_no
# 0          0

# %% [markdown]
# ### Move Feature

# %%
import shutil
import glob
# move_list = glob.glob('../features/1_first_valid/*.gz')
# move_list = glob.glob('../features/2_second_valid/*.gz')
# move_list = glob.glob('../features/3_third_valid/*.gz')
move_list = glob.glob('../features/4_winner/*.gz')
# move_list = glob.glob('../features/5_tmp/*.gz')
# feat_list = list(select_feats[select_feats<3.653].index)
feat_list = list(dec_feat['Unnamed: 0'].values)

for feat in feat_list:
    move_path = [move for move in move_list if move.count(feat[8:])]
    for path in move_path:
#         try:
#             shutil.move(path, '../features/5_tmp/')
#             shutil.move(path, '../features/6_subset/')
#             print(path)
#         except Error:
#             print(f"Error: {path}")
        shutil.move(path, '../features/6_subset/')

# %% [markdown]
# ### OUTLIER SCORE

# %%
import re
from tqdm import tqdm
from sklearn.metrics import mean_squared_error

# outlierに対するスコアを出す
train = utils.read_df_pkl('../input/train0*')
out_ids = train.loc[train.target<-30, key].values
out_val = train.loc[train.target<-30, target].values

# outlier以外に対するスコアを出す
com_ids = train.loc[train.target>-30, key].values
com_val = train.loc[train.target>-30, target].values

path_list = glob.glob('../log_submit/01*csv')
stack_list = glob.glob('../stack/*gz')

out_dict = {}
for i, path in enumerate(tqdm(path_list)):
    tmp_path = path.replace(".", '-')
    cv = re.search(r'CV([^/.]*)_LB', tmp_path).group(1)[:-2].replace('.', '-')
    lb = re.search(r'LB([^/.]*).csv', tmp_path).group(1).replace('-', '.')
    stack_path = [s for s in stack_list if s.count(cv.replace('.', '-'))][0]
    
    df_pred = utils.read_pkl_gzip(stack_path)
    
    if len(df_pred.columns)>3:
        com_pred = df_pred[df_pred[key].isin(com_ids)]['pred_mean'].values
        out_pred = df_pred[df_pred[key].isin(out_ids)]['pred_mean'].values
    else:
        com_pred = df_pred[df_pred[key].isin(com_ids)]['prediction'].values
        out_pred = df_pred[df_pred[key].isin(out_ids)]['prediction'].values
        
    com_score = np.sqrt(mean_squared_error(com_val, com_pred))
    out_score = np.sqrt(mean_squared_error(out_val, out_pred))
    out_vals = {
        '1_CV' : cv.replace('-', '.'),
        '2_LB' : lb,
        '3_OUT': out_score,
        '4_COM': com_score,
               }
    out_dict[str(i)] = out_vals
    
result = pd.DataFrame(out_dict)
display(result.T)
sys.exit()
tmp = result.T['1_CV'][result.T['1_CV']=='3.65133231891838'].index
base = result[tmp]
comp = (result.astype('float').values - base.astype('float').values).T
df = pd.DataFrame(comp.T, columns=result.loc['1_CV', :], index=result.index).T
df.sort_values(by="3_OUT", inplace=True)
display(df)
# Out:
#                 1_CV   2_LB    3_OUT    4_COM
# 0   3.65355624338910  3.694  30.2332  2.07016
# 1   3.64974950464612  3.692  30.1923  2.06493
# 2   3.65034218515939  3.692  30.1928  2.06292
# 3   3.64792661879997  3.691  30.2424  2.06517
# 4    3.6477805039053  3.691  30.2137  2.07579
# 5    3.6512463628215  3.690  30.2132   2.0755
# 6    3.6502284533032  3.690  30.2168  2.05997
# 7   3.65167019701916  3.690  30.2167  2.07578
# 8   3.65133231891838  3.689  30.2033  2.07722
# 9   3.64877091222210  3.698  30.1758  2.06424
# 10   3.6504356599839  3.690  30.2191  2.06058
# 11   3.6506104984303  3.689  30.2056    2.063
# 12   3.6505992354373  3.690  30.2001  2.06373
# 13   3.6509309614642  3.691  30.2075  2.06249
# 14   3.6492385751642  3.691  30.2229  2.06876
# 15  3.65001161936955  3.689  30.2054  2.07394
# 16  3.65263398092539  3.694  30.2718   2.0669
# 17   3.6522145906721  3.692  30.2612  2.06384
# 18    3.649739659357  3.692  30.2025  2.07362
# 19   3.6485124054791  3.693   30.226  2.08269
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %% [markdown]
# ### clf score

# %%
import pandas as pd
pd.set_option('max_rows', 200)

### multi feature pred valid
df = pd.read_csv('../output/0106_16_elo_clf_multi_feat_valid.csv')
select_feats = df.iloc[5, :]
select_feats = select_feats[select_feats!=0][select_feats<1].sort_values(ascending=False)
display(select_feats['0_base'])
display(select_feats.head(50))
# Out:
# 0.9011797851319024
# 204_auth1_category_2_5_0_purchase_amount_max@     0.903103
# 215_auth1_category_2_4_0_purchase_amount_sum@     0.902947
# 231_new_category_1_Y_purchase_amount_min@         0.902927
# 76_new_category_1_N_diff_days_std@                0.902743
# 199_new_category_2_3_0_purchase_amount_max@       0.902732
# 226_auth1_category_3_C_purchase_amount_sum@       0.902675
# 189_auth0_category_3_B_record_sum@                0.902622
# 144_auth1_category_3_B_purchase_amount_mean@      0.902592
# 107_new_category_2_1_0_purchase_amount_mean@      0.902548
# 101_auth0_category_2_1_0_record_sum@              0.902501
# 230_new_category_3_A_purchase_amount_min@         0.902494
# 176_new_category_2_4_0_record_sum@                0.902485
# 73_auth0_category_1_N_purchase_amount_sum@        0.902480
# 26_auth0_category_2_5_0_purchase_amount_sum@      0.902475
# 164_new_category_3_C_diff_days_mean@              0.902475
# 138_new_category_3_B_purchase_amount_sum@         0.902471
# 6_auth0_category_3_A_diff_days_mean@              0.902405
# 129_new_category_3_C_purchase_amount_max@         0.902385
# 44_auth1_category_1_Y_purchase_amount_mean@       0.902361
# 20_new_category_2_2_0_purchase_amount_min@        0.902355
# 64_auth0_category_2_5_0_purchase_amount_max@      0.902351
# 14_new_category_2_5_0_purchase_amount_min@        0.902348
# 28_auth0_category_3_B_record_sum_ratio@           0.902338
# 27_auth0_category_2_4_0_diff_days_mean@           0.902315
# 84_auth0_category_1_Y_diff_days_mean@             0.902313
# 219_auth0_category_3_A_purchase_amount_min@       0.902284
# 198_auth1_category_2_1_0_purchase_amount_mean@    0.902271
# 147_auth0_category_3_B_purchase_amount_min@       0.902256
# 87_auth1_category_2_2_0_diff_days_mean@           0.902252
# 191_new_category_1_N_purchase_amount_max@         0.902249
# 93_auth1_category_2_5_0_purchase_amount_min@      0.902234
# 192_auth0_category_1_Y_purchase_amount_min@       0.902213
# 130_auth1_category_3_A_purchase_amount_max@       0.902209
# 21_new_category_2_2_0_purchase_amount_sum@        0.902202
# 209_new_category_2_5_0_record_sum@                0.902196
# 114_new_category_2_3_0_diff_days_std@             0.902194
# 171_auth0_category_2_1_0_purchase_amount_sum@     0.902179
# 139_auth1_category_2_4_0_purchase_amount_min@     0.902170
# 179_auth0_category_2_4_0_purchase_amount_sum@     0.902161
# 30_auth1_category_2_1_0_purchase_amount_min@      0.902145
# 244_auth0_category_2_5_0_diff_days_mean@          0.902144
# 55_auth0_category_2_3_0_record_sum_ratio@         0.902125
# 165_new_category_3_C_purchase_amount_min@         0.902117
# 159_new_category_2_5_0_diff_days_std@             0.902109
# 221_auth0_category_3_A_record_sum@                0.902098
# 110_auth1_category_1_Y_record_sum@                0.902087
# 223_new_category_3_B_record_sum_ratio@            0.902050
# 208_auth1_category_2_3_0_diff_days_std@           0.902040
# 77_auth1_category_3_B_record_sum@                 0.902040
# 135_auth0_category_2_4_0_purchase_amount_mean@    0.902039
# Name: 5, dtype: float64

# %%
import shutil
import glob
move_list = glob.glob('../features/1_first_valid/*.gz')
feat_list = list(select_feats[select_feats>0.902].index)

for feat in feat_list:
    move_path = [move for move in move_list if move.count(feat[6:])]
    for path in move_path:
        try:
            shutil.move(path, '../features/5_tmp/')
#             print(path)
        except Error:
            print(f"Error: {path}")

# %% [markdown]
# ### Clf output to Tableau

# %%
train = utils.read_df_pkl('../input/train0*')
clf = utils.read_pkl_gzip('../stack/0111_145_outlier_classify_9seed_lgb_binary_CV0-9045939277654236_188features.gz')
for col in clf:
    if col==key:continue
    clf.rename(columns={col:f"clf_{col}"}, inplace=True)
clf = clf.merge(train, how='left', on=key)
clf.to_csv('../output/0111_145_elo_eda_outlier_classify_9seed_lgb_binary_CV0-9045939277654236_188features.csv', index=False)
# Out:
# 100%|██████████| 3/3 [00:00<00:00, 32.61it/s]

# %%
start_time = "{0:%Y%m%d_%H%M%S}".format(datetime.datetime.now())
#========================================================================
# Data Load
base = utils.read_df_pkl('../input/base*')
win_path_list = glob.glob(win_path)
# tmp_path_listには検証中のfeatureを入れてある
tmp_path_list = glob.glob('../features/5_tmp/*.gz')
win_path_list += tmp_path_list

train_path_list = []
test_path_list = []
for path in win_path_list:
    if path.count('train'):
        train_path_list.append(path)
    elif path.count('test'):
        test_path_list.append(path)

base_train = base[~base[target].isnull()].reset_index(drop=True)
base_test = base[base[target].isnull()].reset_index(drop=True)
train_feature_list = utils.parallel_load_data(path_list=train_path_list)
test_feature_list = utils.parallel_load_data(path_list=test_path_list)
train = pd.concat(train_feature_list, axis=1)
train = pd.concat([base_train, train], axis=1)
test = pd.concat(test_feature_list, axis=1)
test = pd.concat([base_test, test], axis=1)

train_test = pd.concat([train, test], axis=0)

reg_exc_out = utils.read_pkl_gzip('../stack/0111_154_stack_lgb_lr0.01_188feats_10seed_OUT29.5523_CV3-3530444409955336_LB.gz')
reg_exc_out_2 = utils.read_pkl_gzip('../stack/0111_102_stack_lgb_lr0.01_188feats_10seed_OUT30.2040_CV3-6494249648406467_LB.gz')
target_cols = [col for col in reg_exc_out if col.count('target_')]

for i, df in zip(['po_', ''], [reg_exc_out, reg_exc_out_2]):
    df.drop(target_cols, axis=1, inplace=True)
    for col in df.columns:
        if col in ignore_list:continue
        df.rename(columns={col:f"{i}{col}"}, inplace=True)

clf = utils.read_pkl_gzip('../stack/0111_145_outlier_classify_9seed_lgb_binary_CV0-9045939277654236_188features.gz')
for col in clf:
    if col==key:continue
    clf.rename(columns={col:f"clf_{col}"}, inplace=True)
clf = clf.merge(train_test, how='left', on=key).merge(reg_exc_out, how='left', on=key).merge(reg_exc_out_2, how='left', on=key)
clf.to_csv(f'../output/{start_time[4:13]}_elo_eda_pred_result_feature_set.csv', index=False)
# Out:
# 100%|██████████| 3/3 [00:00<00:00, 90.85it/s]
